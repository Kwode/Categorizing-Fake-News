# %%
import pandas as pd
import spacy
import nltk

# %%
fake_data = pd.read_csv('fake_news_data.csv')
fake_data.head()
fake_news = fake_data[['text', 'fake_or_factual']]
fake_news.head()
# Out:
#                                                 text fake_or_factual
# 0  There are two small problems with your analogy...       Fake News
# 1  Buried in Trump s bonkers interview with New Y...       Fake News
# 2  Women make up over 50 percent of this country,...       Fake News
# 3  WASHINGTON (Reuters) - U.S. Defense Secretary ...    Factual News
# 4  BELFAST (Reuters) - Northern Ireland s politic...    Factual News

# %% [markdown]
# POS TAGGING

# %%
nlp = spacy.load('en_core_web_sm')
fake_news = fake_data[fake_data['fake_or_factual'] == 'Fake News']
factual_news = fake_data[fake_data['fake_or_factual'] == 'Factual News']

fake_spacy_doc = list(nlp.pipe(fake_news['text']))
factual_spacy_doc = list(nlp.pipe(factual_news['text']))
# Out:
#                                                title  \
# 0  HOLLYWEIRD LIB SUSAN SARANDON Compares Muslim ...
# 1   Elijah Cummings Called Trump Out To His Face ...
# 2   Hillary Clinton Says Half Her Cabinet Will Be...
# 5  Maxine Waters Makes Teens Chant ‘Impeach 45′ a...
# 6   Jay Carney Let It Slip That He Knows Who Obam...
#
#                                                 text               date  \
# 0  There are two small problems with your analogy...       Dec 30, 2015
# 1  Buried in Trump s bonkers interview with New Y...      April 6, 2017
# 2  Women make up over 50 percent of this country,...     April 26, 2016
# 5  Shame on Teen Vogue! Maxine Waters was a guest...       Dec 10, 2017
# 6  Former White House Press Secretary in the Obam...  February 10, 2016
#
#   fake_or_factual
# 0       Fake News
# 1       Fake News
# 2       Fake News
# 5       Fake News
# 6       Fake News

# %%
fake_tags = []

for doc in fake_spacy_doc: 
    fake_tags.append([{'token': token.text, 'pos tags': token.pos_, 'ner': token.ent_type_} for token in doc])

fake_tags[1][0]
# Out:
# {'token': 'Buried', 'pos tags': 'VERB', 'ner': ''}
